# %%
import itertools
import numpy

# %%
for c in itertools.product([16, 64, 256], [16, 64, 256], [16, 64, 256]):
    if numpy.sum(c) < 500:
        print("%s,%s,%s,%s,%s" % (c[0], c[1], c[2], numpy.std(numpy.log(c)) / numpy.mean(numpy.log(c)), numpy.log(c[0] + c[1] + c[2])))
# Out:
# 16,16,16,0.0,3.871201010907891
# 16,16,64,0.2020305089104421,4.564348191467836
# 16,16,256,0.3535533905932738,5.662960480135946
# 16,64,16,0.2020305089104421,4.564348191467836
# 16,64,64,0.17677669529663687,4.969813299576001
# 16,64,256,0.2721655269759087,5.817111159963204
# 16,256,16,0.3535533905932738,5.662960480135946
# 16,256,64,0.2721655269759087,5.817111159963204
# 64,16,16,0.2020305089104421,4.564348191467836
# 64,16,64,0.17677669529663687,4.969813299576001
# 64,16,256,0.2721655269759087,5.817111159963204
# 64,64,16,0.17677669529663684,4.969813299576001
# 64,64,64,0.0,5.2574953720277815
# 64,64,256,0.14142135623730956,5.950642552587727
# 64,256,16,0.2721655269759087,5.817111159963204
# 64,256,64,0.14142135623730956,5.950642552587727
# 256,16,16,0.3535533905932738,5.662960480135946
# 256,16,64,0.2721655269759087,5.817111159963204
# 256,64,16,0.2721655269759087,5.817111159963204
# 256,64,64,0.14142135623730956,5.950642552587727
